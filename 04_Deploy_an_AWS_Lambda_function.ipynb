# %% [markdown]
# # **04** - Deploy an AWS Lambda function

# %% [markdown]
# ### Import all needed packages

# %%
import boto3, os

# %%
from helpers.Lambda_Helper import Lambda_Helper
from helpers.S3_Helper import S3_Helper
from helpers.Display_Helper import Display_Helper

# %%
lambda_helper = Lambda_Helper()
# deploy_function
# add_lambda_trigger

# %%
s3_helper = S3_Helper()
# upload_file
# download_object 
# list_objects

# %%
display_helper = Display_Helper()
# text_file
# json_file

# %%
bucket_name_text = os.environ['LEARNERS3BUCKETNAMETEXT']

# %%
# %%writefile prompt_template.txt
# I need to summarize a conversation. The transcript of the conversation is between the <data> XML like tags.
#
# <data>
# {{transcript}}
# </data>
#
# The summary must contain a one word sentiment analysis, and a list of issues, problems or causes of friction
# during the conversation. The output must be provided in JSON format shown in the following example.
#
# Example output:
# {
#     "version": 0.1,
#     "sentiment": <sentiment>,
#     "issues": [
#         {
#             "topic": <topic>,
#             "summary": <issue_summary>,
#         }
#     ]
# }
#
# An `issue_summary` must only be one of:
# {%- for topic in topics %}
#  - `{{topic}}`
# {% endfor %}
#
# Write the JSON output and nothing more.
#
# Here is the JSON output:
# Out:
# Overwriting prompt_template.txt

# %%
display_helper.text_file('prompt_template.txt')
# Out:
# prompt_template.txt:
# <div style='width: 600px; word-wrap: break-word;'><pre>I need to summarize a conversation. The transcript of the conversation is between the &lt;data&gt; XML like tags.<br><br>&lt;data&gt;<br>{{transcript}}<br>&lt;/data&gt;<br><br>The summary must contain a one word sentiment analysis, and a list of issues, problems or causes of friction<br>during the conversation. The output must be provided in JSON format shown in the following example. <br><br>Example output:<br>{<br>    &quot;version&quot;: 0.1,<br>    &quot;sentiment&quot;: &lt;sentiment&gt;,<br>    &quot;issues&quot;: [<br>        {<br>            &quot;topic&quot;: &lt;topic&gt;,<br>            &quot;summary&quot;: &lt;issue_summary&gt;,<br>        }<br>    ]<br>}<br><br>An `issue_summary` must only be one of:<br>{%- for topic in topics %}<br> - `{{topic}}`<br>{% endfor %}<br><br>Write the JSON output and nothing more.<br><br>Here is the JSON output:<br></pre></div>

# %% [markdown]
# ### Create the Lambda function
#
# * event: It contains the Payload when something is triggered in AWS (e.g., object uploaded to S3)
# * context: The data about the execution environment of the function

# %%
# %%writefile lambda_function.py


#############################################################
#
# This Lambda function is written to a file by the notebook 
# It does not run in the notebook!
#
#############################################################

import boto3
import json 
from jinja2 import Template

s3_client = boto3.client('s3')
bedrock_runtime = boto3.client('bedrock-runtime', 'us-west-2')

def lambda_handler(event, context):
    
    bucket = event['Records'][0]['s3']['bucket']['name']
    key = event['Records'][0]['s3']['object']['key']
    
    # One of a few different checks to ensure we don't end up in a recursive loop.
    if "-transcript.json" not in key: 
        print("This demo only works with *-transcript.json.")
        return
    
    try: 
        file_content = ""
        
        response = s3_client.get_object(Bucket=bucket, Key=key)
        
        file_content = response['Body'].read().decode('utf-8')
        
        transcript = extract_transcript_from_textract(file_content)

        print(f"Successfully read file {key} from bucket {bucket}.")

        print(f"Transcript: {transcript}")
        
        summary = bedrock_summarisation(transcript)
        
        s3_client.put_object(
            Bucket=bucket,
            Key='results.txt',
            Body=summary,
            ContentType='text/plain'
        )
        
    except Exception as e:
        print(f"Error occurred: {e}")
        return {
            'statusCode': 500,
            'body': json.dumps(f"Error occurred: {e}")
        }

    return {
        'statusCode': 200,
        'body': json.dumps(f"Successfully summarized {key} from bucket {bucket}. Summary: {summary}")
    }
        
        
        
def extract_transcript_from_textract(file_content):

    transcript_json = json.loads(file_content)

    output_text = ""
    current_speaker = None

    items = transcript_json['results']['items']

    # Iterate through the content word by word:
    for item in items:
        speaker_label = item.get('speaker_label', None)
        content = item['alternatives'][0]['content']
        
        # Start the line with the speaker label:
        if speaker_label is not None and speaker_label != current_speaker:
            current_speaker = speaker_label
            output_text += f"\n{current_speaker}: "
        
        # Add the speech content:
        if item['type'] == 'punctuation':
            output_text = output_text.rstrip()  # Remove the last space
        
        output_text += f"{content} "
        
    return output_text
        

def bedrock_summarisation(transcript):
    
    with open('prompt_template.txt', "r") as file:
        template_string = file.read()

    data = {
        'transcript': transcript,
        'topics': ['charges', 'location', 'availability']
    }
    
    template = Template(template_string)
    prompt = template.render(data)
    
    print(prompt)
    
    kwargs = {
        "modelId": "amazon.titan-text-express-v1",
        "contentType": "application/json",
        "accept": "*/*",
        "body": json.dumps(
            {
                "inputText": prompt,
                "textGenerationConfig": {
                    "maxTokenCount": 2048,
                    "stopSequences": [],
                    "temperature": 0,
                    "topP": 0.9
                }
            }
        )
    }
    
    response = bedrock_runtime.invoke_model(**kwargs)

    summary = json.loads(response.get('body').read()).get('results')[0].get('outputText')    
    return summary
# Out:
# Writing lambda_function.py

# %%
lambda_helper.deploy_function(
    ["lambda_function.py", "prompt_template.txt"],
    function_name="LambdaFunctionSummarize"
)
# Out:
# Zipping function...
# Looking for existing function...
# Function LambdaFunctionSummarize does not exist. Creating...
# Function LambdaFunctionSummarize created: arn:aws:lambda:us-west-2:709661985547:function:LambdaFunctionSummarize
# Done.

# %%
lambda_helper.filter_rules_suffix = "json"
lambda_helper.add_lambda_trigger(bucket_name_text)
# Out:
# Using function name of deployed function: LambdaFunctionSummarize
# Permission added with Statement: {
#     "Sid": "s3-trigger-permission",
#     "Effect": "Allow",
#     "Principal": {
#         "Service": "s3.amazonaws.com"
#     },
#     "Action": "lambda:InvokeFunction",
#     "Resource": "arn:aws:lambda:us-west-2:709661985547:function:LambdaFunctionSummarize",
#     "Condition": {
#         "ArnLike": {
#             "AWS:SourceArn": "arn:aws:s3:::c99355a2566046l5856239t1w709661985-learners3bucket-sx9koia8f5ic"
#         }
#     }
# }
# Trigger added for c99355a2566046l5856239t1w709661985-learners3bucket-sx9koia8f5ic -> LambdaFunctionSummarize

# %%
display_helper.json_file('demo-transcript.json')
# Out:
# demo-transcript.json:
# {
#     "jobName": "transcription-job-b6458c15-9b9a-4b39-9f7b-1503fafbfd09",
#     "accountId": "157708787616",
#     "status": "COMPLETED",
#     "results": {
#         "transcripts": [
#             {
#                 "transcript": "Hi, is this the Crystal Heights Hotel in Singapore? Yes, it is. Good afternoon. How may I assist you today? Fantastic, good afternoon. I was looking to book a room for my 10th wedding anniversary. Ive heard your hotel offers exceptional views and services. Could you tell me more? Absolutely, Alex and congratulations on your upcoming anniversary. Thats a significant milestone and wed be honored to make it a special occasion for you. We have several room types that offer stunning views of the city skyline and the fictional Sapphire Bay. Our special diamond suite even comes with exclusive access to the moonlit pool and star deck. We also have in house spa services, world class dining options and a shopping arcade. That sounds heavenly. I think my spouse would love the moonlit pool. Can you help me make a reservation for one of your diamond suites with a sapphire bay view? Of course. May I know the dates you planning to visit? Sure. It would be from October 10th to 17th. Excellent. Let me check the availability. Ah It looks like we have a diamond suite available for those dates. Would you like to proceed with the reservation? Definitely. Whats included in the package? Wonderful. The package includes breakfast, complimentary access to the moonlit pool and star deck. A one time spa treatment for two and a special romantic dinner at our cloud nine restaurant. You making it impossible to resist. Lets go ahead with the booking. Great. I'll need some personal information for the reservation. Can I get your full name, contact details and a credit card for the preauthorizations? Certainly. My full name is Alexander Thompson. My contact number is 12345678910. And the credit card is, wait, did you say pre authorization? How much would that be? Ah, I should have mentioned that earlier. My apologies. A pre authorization. A mt of $1000 will be held on your card which would be released upon checkout $1000. That seems a bit excessive. Don't you think I understand your concern, Alex. The pre authorization is a standard procedure to cover any incidental expenses you may incur during your stay. However, I assure you its only a hold and not an actual charge. Thats still a lot. Are there any additional charges that I should know about? Well, there is a 10% service charge and a 7% fantasy tax applied to the room rate. Mm. You know what its a special occasion. So lets go ahead. Thank you, Alex for understanding. Will ensure that your experience at Crystal Heights is well worth it."
#             }
#         ],
#         "speaker_labels": {
#             "segments": [
#                 {
#                     "start_time": "0.0",
#                     "end_time": "3.069",
#                     "speaker_label": "spk_0",
#                     "items": [
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "0.079",
#                             "end_time": "0.509"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "0.519",
#                             "end_time": "0.709"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "0.72",
#                             "end_time": "0.949"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "0.959",
#                             "end_time": "1.049"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "1.059",
#                             "end_time": "1.419"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "1.429",
#                             "end_time": "1.72"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "1.73",
#                             "end_time": "2.14"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "2.15",
#                             "end_time": "2.23"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "2.24",
#                             "end_time": "2.93"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "3.789",
#                     "end_time": "8.0",
#                     "speaker_label": "spk_1",
#                     "items": [
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "3.799",
#                             "end_time": "4.09"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "4.099",
#                             "end_time": "4.239"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "4.25",
#                             "end_time": "4.769"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "5.059",
#                             "end_time": "5.4"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "5.409",
#                             "end_time": "6.07"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "6.449",
#                             "end_time": "6.699"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "6.71",
#                             "end_time": "6.9"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "6.909",
#                             "end_time": "6.94"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "6.949",
#                             "end_time": "7.34"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "7.349",
#                             "end_time": "7.44"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "7.449",
#                             "end_time": "7.9"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "8.659",
#                     "end_time": "19.469",
#                     "speaker_label": "spk_0",
#                     "items": [
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "8.829",
#                             "end_time": "9.649"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "9.659",
#                             "end_time": "9.93"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "9.939",
#                             "end_time": "10.59"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "11.079",
#                             "end_time": "11.229"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "11.239",
#                             "end_time": "11.409"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "11.42",
#                             "end_time": "11.71"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "11.72",
#                             "end_time": "11.81"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "11.819",
#                             "end_time": "12.05"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "12.06",
#                             "end_time": "12.069"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "12.079",
#                             "end_time": "12.39"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "12.399",
#                             "end_time": "12.529"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "12.539",
#                             "end_time": "12.689"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "12.699",
#                             "end_time": "13.01"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "13.02",
#                             "end_time": "13.3"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "13.31",
#                             "end_time": "14.13"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "14.529",
#                             "end_time": "14.75"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "14.76",
#                             "end_time": "14.989"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "15.0",
#                             "end_time": "15.13"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "15.14",
#                             "end_time": "15.63"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "15.64",
#                             "end_time": "15.97"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "15.979",
#                             "end_time": "16.569"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "16.579",
#                             "end_time": "16.889"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "16.899",
#                             "end_time": "17.0"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "17.01",
#                             "end_time": "17.819"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "18.11",
#                             "end_time": "18.459"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "18.469",
#                             "end_time": "18.569"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "18.579",
#                             "end_time": "18.809"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "18.819",
#                             "end_time": "18.94"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "18.95",
#                             "end_time": "19.37"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "20.129",
#                     "end_time": "46.529",
#                     "speaker_label": "spk_1",
#                     "items": [
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "20.209",
#                             "end_time": "20.92"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "20.93",
#                             "end_time": "21.52"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "21.53",
#                             "end_time": "21.719"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "21.729",
#                             "end_time": "22.629"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "22.639",
#                             "end_time": "22.76"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "22.77",
#                             "end_time": "22.92"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "22.93",
#                             "end_time": "23.42"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "23.43",
#                             "end_time": "24.159"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "24.62",
#                             "end_time": "25.069"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "25.079",
#                             "end_time": "25.09"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "25.1",
#                             "end_time": "25.62"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "25.629",
#                             "end_time": "26.399"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "26.409",
#                             "end_time": "26.639"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "26.649",
#                             "end_time": "26.809"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "26.819",
#                             "end_time": "26.959"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "26.969",
#                             "end_time": "27.34"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "27.35",
#                             "end_time": "27.44"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "27.45",
#                             "end_time": "27.68"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "27.69",
#                             "end_time": "27.78"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "27.79",
#                             "end_time": "27.799"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "27.809",
#                             "end_time": "28.239"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "28.25",
#                             "end_time": "28.719"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "28.729",
#                             "end_time": "28.94"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "28.95",
#                             "end_time": "29.18"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "29.59",
#                             "end_time": "29.84"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "29.85",
#                             "end_time": "30.11"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "30.12",
#                             "end_time": "30.44"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "30.45",
#                             "end_time": "30.709"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "30.719",
#                             "end_time": "31.1"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "31.11",
#                             "end_time": "31.26"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "31.27",
#                             "end_time": "31.62"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "31.629",
#                             "end_time": "32.04"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "32.049",
#                             "end_time": "32.36"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "32.369",
#                             "end_time": "32.479"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "32.49",
#                             "end_time": "32.59"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "32.599",
#                             "end_time": "32.84"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "32.849",
#                             "end_time": "33.479"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "33.49",
#                             "end_time": "33.63"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "33.639",
#                             "end_time": "33.72"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "33.729",
#                             "end_time": "34.229"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "34.24",
#                             "end_time": "34.77"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "34.779",
#                             "end_time": "35.2"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "35.49",
#                             "end_time": "35.88"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "35.889",
#                             "end_time": "36.34"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "36.349",
#                             "end_time": "36.77"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "36.779",
#                             "end_time": "37.049"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "37.06",
#                             "end_time": "37.36"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "37.369",
#                             "end_time": "37.659"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "37.669",
#                             "end_time": "37.84"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "37.849",
#                             "end_time": "38.36"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "38.369",
#                             "end_time": "38.799"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "38.81",
#                             "end_time": "38.95"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "38.959",
#                             "end_time": "39.04"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "39.049",
#                             "end_time": "39.479"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "39.49",
#                             "end_time": "39.869"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "39.88",
#                             "end_time": "40.0"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "40.009",
#                             "end_time": "40.319"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "40.33",
#                             "end_time": "40.74"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "41.04",
#                             "end_time": "41.36"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "41.369",
#                             "end_time": "41.72"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "41.729",
#                             "end_time": "41.959"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "41.97",
#                             "end_time": "42.04"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "42.049",
#                             "end_time": "42.43"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "42.439",
#                             "end_time": "42.63"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "42.639",
#                             "end_time": "43.4"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "43.409",
#                             "end_time": "43.74"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "43.75",
#                             "end_time": "44.029"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "44.04",
#                             "end_time": "44.389"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "44.4",
#                             "end_time": "45.08"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "45.09",
#                             "end_time": "45.29"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "45.299",
#                             "end_time": "45.31"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "45.319",
#                             "end_time": "45.759"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "45.77",
#                             "end_time": "46.4"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "47.319",
#                     "end_time": "56.159",
#                     "speaker_label": "spk_0",
#                     "items": [
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "47.369",
#                             "end_time": "47.59"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "47.599",
#                             "end_time": "47.959"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "47.97",
#                             "end_time": "48.639"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "49.009",
#                             "end_time": "49.02"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "49.04",
#                             "end_time": "49.389"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "49.4",
#                             "end_time": "49.54"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "49.549",
#                             "end_time": "49.909"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "49.919",
#                             "end_time": "50.09"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "50.099",
#                             "end_time": "50.24"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "50.25",
#                             "end_time": "50.349"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "50.36",
#                             "end_time": "50.75"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "50.759",
#                             "end_time": "51.31"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "51.599",
#                             "end_time": "51.909"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "51.919",
#                             "end_time": "52.0"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "52.009",
#                             "end_time": "52.229"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "52.24",
#                             "end_time": "52.349"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "52.36",
#                             "end_time": "52.599"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "52.61",
#                             "end_time": "52.619"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "52.63",
#                             "end_time": "53.27"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "53.279",
#                             "end_time": "53.47"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "53.479",
#                             "end_time": "53.599"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "53.61",
#                             "end_time": "53.689"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "53.7",
#                             "end_time": "53.84"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "53.849",
#                             "end_time": "54.25"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "54.259",
#                             "end_time": "54.65"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "54.659",
#                             "end_time": "54.86"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "54.869",
#                             "end_time": "54.88"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "54.889",
#                             "end_time": "55.43"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "55.439",
#                             "end_time": "55.639"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "55.65",
#                             "end_time": "56.029"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "56.819",
#                     "end_time": "60.27",
#                     "speaker_label": "spk_1",
#                     "items": [
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "56.909",
#                             "end_time": "57.13"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "57.139",
#                             "end_time": "57.759"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "58.139",
#                             "end_time": "58.409"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "58.419",
#                             "end_time": "58.529"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "58.54",
#                             "end_time": "58.729"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "58.74",
#                             "end_time": "58.849"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "58.86",
#                             "end_time": "59.13"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "59.139",
#                             "end_time": "59.259"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "59.29",
#                             "end_time": "59.639"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "59.65",
#                             "end_time": "59.759"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "59.77",
#                             "end_time": "60.169"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "61.049",
#                     "end_time": "64.058",
#                     "speaker_label": "spk_0",
#                     "items": [
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "61.13",
#                             "end_time": "61.659"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "61.669",
#                             "end_time": "61.799"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "61.81",
#                             "end_time": "61.959"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "61.97",
#                             "end_time": "62.119"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "62.13",
#                             "end_time": "62.29"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "62.299",
#                             "end_time": "62.74"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "62.75",
#                             "end_time": "63.08"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "63.09",
#                             "end_time": "63.15"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "63.159",
#                             "end_time": "63.919"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "64.76",
#                     "end_time": "74.489",
#                     "speaker_label": "spk_1",
#                     "items": [
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "64.769",
#                             "end_time": "65.589"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "65.9",
#                             "end_time": "66.19"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "66.199",
#                             "end_time": "66.279"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "66.29",
#                             "end_time": "66.51"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "66.519",
#                             "end_time": "66.589"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "66.599",
#                             "end_time": "67.47"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "67.76",
#                             "end_time": "68.26"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "68.66",
#                             "end_time": "68.87"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "68.879",
#                             "end_time": "69.15"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "69.16",
#                             "end_time": "69.309"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "69.319",
#                             "end_time": "69.47"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "69.48",
#                             "end_time": "69.68"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "69.69",
#                             "end_time": "69.699"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "69.709",
#                             "end_time": "70.16"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "70.169",
#                             "end_time": "70.41"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "70.419",
#                             "end_time": "70.91"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "70.919",
#                             "end_time": "71.05"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "71.059",
#                             "end_time": "71.309"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "71.319",
#                             "end_time": "71.91"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "72.269",
#                             "end_time": "72.58"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "72.589",
#                             "end_time": "72.669"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "72.68",
#                             "end_time": "72.889"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "72.9",
#                             "end_time": "72.989"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "73.0",
#                             "end_time": "73.389"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "73.4",
#                             "end_time": "73.55"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "73.559",
#                             "end_time": "73.639"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "73.65",
#                             "end_time": "74.389"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "75.269",
#                     "end_time": "78.29",
#                     "speaker_label": "spk_0",
#                     "items": [
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "75.279",
#                             "end_time": "76.12"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "76.58",
#                             "end_time": "76.9"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "76.91",
#                             "end_time": "77.389"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "77.4",
#                             "end_time": "77.459"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "77.47",
#                             "end_time": "77.55"
#                         },
#                         {
#                             "speaker_label": "spk_0",
#                             "start_time": "77.559",
#                             "end_time": "78.139"
#                         }
#                     ]
#                 },
#                 {
#                     "start_time": "79.01",
#                     "end_time": "90.339",
#                     "speaker_label": "spk_1",
#                     "items": [
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "79.089",
#                             "end_time": "79.79"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "80.129",
#                             "end_time": "80.25"
#                         },
#                         {
#                             "speaker_label": "spk_1",
#                             "start_time": "80.26",
#                             "end_time": "80.68"
#                         },
#                         {
# ...
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.9490000000000001",
#                         "content": "7%"
#                     }
#                 ],
#                 "start_time": "155.789",
#                 "end_time": "156.58",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.998",
#                         "content": "fantasy"
#                     }
#                 ],
#                 "start_time": "156.589",
#                 "end_time": "157.02",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "tax"
#                     }
#                 ],
#                 "start_time": "157.029",
#                 "end_time": "157.41",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.998",
#                         "content": "applied"
#                     }
#                 ],
#                 "start_time": "157.419",
#                 "end_time": "157.83",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "to"
#                     }
#                 ],
#                 "start_time": "157.839",
#                 "end_time": "157.929",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "the"
#                     }
#                 ],
#                 "start_time": "157.94",
#                 "end_time": "158.02",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "room"
#                     }
#                 ],
#                 "start_time": "158.029",
#                 "end_time": "158.32",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.996",
#                         "content": "rate"
#                     }
#                 ],
#                 "start_time": "158.33",
#                 "end_time": "158.649",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.728",
#                         "content": "Mm"
#                     }
#                 ],
#                 "start_time": "159.589",
#                 "end_time": "159.88",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "You"
#                     }
#                 ],
#                 "start_time": "160.07",
#                 "end_time": "160.33",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "know"
#                     }
#                 ],
#                 "start_time": "160.339",
#                 "end_time": "160.46",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "what"
#                     }
#                 ],
#                 "start_time": "160.47",
#                 "end_time": "160.86",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "its"
#                     }
#                 ],
#                 "start_time": "160.869",
#                 "end_time": "161.029",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "a"
#                     }
#                 ],
#                 "start_time": "161.039",
#                 "end_time": "161.05",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "special"
#                     }
#                 ],
#                 "start_time": "161.059",
#                 "end_time": "161.619",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "occasion"
#                     }
#                 ],
#                 "start_time": "161.63",
#                 "end_time": "162.179",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "So"
#                     }
#                 ],
#                 "start_time": "162.19",
#                 "end_time": "162.44",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "lets"
#                     }
#                 ],
#                 "start_time": "162.449",
#                 "end_time": "162.69",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "go"
#                     }
#                 ],
#                 "start_time": "162.699",
#                 "end_time": "162.86",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "ahead"
#                     }
#                 ],
#                 "start_time": "162.869",
#                 "end_time": "163.3",
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_0"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "Thank"
#                     }
#                 ],
#                 "start_time": "164.199",
#                 "end_time": "164.61",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "you"
#                     }
#                 ],
#                 "start_time": "164.619",
#                 "end_time": "164.889",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": ","
#                     }
#                 ],
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.941",
#                         "content": "Alex"
#                     }
#                 ],
#                 "start_time": "164.899",
#                 "end_time": "165.449",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "for"
#                     }
#                 ],
#                 "start_time": "165.46",
#                 "end_time": "165.75",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "understanding"
#                     }
#                 ],
#                 "start_time": "165.759",
#                 "end_time": "166.49",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "Will"
#                     }
#                 ],
#                 "start_time": "166.8",
#                 "end_time": "167.059",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.996",
#                         "content": "ensure"
#                     }
#                 ],
#                 "start_time": "167.07",
#                 "end_time": "167.509",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "that"
#                     }
#                 ],
#                 "start_time": "167.52",
#                 "end_time": "167.63",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "your"
#                     }
#                 ],
#                 "start_time": "167.639",
#                 "end_time": "167.83",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "experience"
#                     }
#                 ],
#                 "start_time": "167.839",
#                 "end_time": "168.55",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "at"
#                     }
#                 ],
#                 "start_time": "168.559",
#                 "end_time": "168.589",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.996",
#                         "content": "Crystal"
#                     }
#                 ],
#                 "start_time": "168.6",
#                 "end_time": "169.029",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "Heights"
#                     }
#                 ],
#                 "start_time": "169.039",
#                 "end_time": "169.33",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "is"
#                     }
#                 ],
#                 "start_time": "169.339",
#                 "end_time": "169.509",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "well"
#                     }
#                 ],
#                 "start_time": "169.52",
#                 "end_time": "169.729",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "worth"
#                     }
#                 ],
#                 "start_time": "169.74",
#                 "end_time": "169.99",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "pronunciation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.999",
#                         "content": "it"
#                     }
#                 ],
#                 "start_time": "170.0",
#                 "end_time": "170.21",
#                 "speaker_label": "spk_1"
#             },
#             {
#                 "type": "punctuation",
#                 "alternatives": [
#                     {
#                         "confidence": "0.0",
#                         "content": "."
#                     }
#                 ],
#                 "speaker_label": "spk_1"
#             }
#         ]
#     }
# }

# %%
s3_helper.upload_file(bucket_name_text, 'demo-transcript.json')
# Out:
# Object 'demo-transcript.json' uploaded to bucket 'c99355a2566046l5856239t1w709661985-learners3bucket-sx9koia8f5ic'

# %% [markdown]
# #### Restart kernel if needed.
# - If you run the code fairly quickly from start to finish, it's possible that the following code cell `s3_helper.list_objects(bucket_name_text)` will give a "Not Found" error.
# - If waiting a few seconds (10 seconds) and re-running this cell does not resolve the error, then you can restart the kernel of the jupyter notebook.
# - Go to menu->Kernel->Restart Kernel.
# - Then run the code cells from the start of the notebook, waiting 2 seconds or so for each code cell to finish executing.

# %%
s3_helper.list_objects(bucket_name_text)
# Out:
# Object: demo-transcript.json, Created on: 2024-02-16 18:41:41+00:00
# Object: results.txt, Created on: 2024-02-16 18:41:47+00:00

# %% [markdown]
# #### Re-run "download" code cell as needed
# - It may take a few seconds for the results to be generated.
# - If you see a `Not Found` error, please wait a few seconds and then try running the `s3_helper.download_object` again.

# %%
s3_helper.download_object(bucket_name_text, "results.txt")
# Out:
# Object 'results.txt' from bucket 'c99355a2566046l5856239t1w709661985-learners3bucket-sx9koia8f5ic' to './results.txt'

# %%
display_helper.text_file('results.txt')
# Out:
# results.txt:
# <div style='width: 600px; word-wrap: break-word;'><pre><br>{<br>    &quot;version&quot;: 0.1,<br>    &quot;sentiment&quot;: &quot;positive&quot;,<br>    &quot;issues&quot;: [<br>        {<br>            &quot;topic&quot;: &quot;charges&quot;,<br>            &quot;summary&quot;: &quot;pre authorization is a standard procedure to cover any incidental expenses you may incur during your stay&quot;<br>        }<br>    ]<br>}</pre></div>
